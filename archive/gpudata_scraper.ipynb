# %%
import sqlite3
from requests import get
from bs4 import BeautifulSoup
import time
import random
import pandas as pd
import re
import math
from json import loads
from IPython.core.display import clear_output
from PCPartPicker_API import pcpartpicker

# %%
#Interface with SQL
def run_query(DB, q):
    with sqlite3.connect(DB) as conn:
        return pd.read_sql(q,conn)

def run_command(DB, c):
    with sqlite3.connect(DB) as conn:
        conn.execute('PRAGMA foreign_keys = ON;')
        conn.isolation_level = None
        conn.execute(c)
        
def run_inserts(DB, c, values):
    with sqlite3.connect(DB) as conn:
        conn.execute('PRAGMA foreign_keys = ON;')
        conn.isolation_level = None
        conn.execute(c, values)

# %%
def scrape_card_list(DB = 'gpudata.db', sleep_min = 5, sleep_max = 15):
    start_time = time.time()
    pages = pcpartpicker.lists.total_pages("video-card")
    
    insert_query = '''
    INSERT OR IGNORE INTO card_specs(
        card_id,
        card_name,
        series,
        chipset_id,
        memory_in_GB,
        core_clock_in_GHz,
        ratings
    ) 
    VALUES (?, ?, ?, ?, ?, ?, ?)
    '''

    insert_query_chipsets = '''
    INSERT OR IGNORE INTO chipsets(
        chipset_name
    ) 
    VALUES (?)
    '''
    
    #Pulls chipsets table from the database
    select_query_chipsets = 'SELECT * FROM chipsets'
    temp_chipsets_table = run_query(DB, select_query_chipsets)
    
    for i in range(1, pages+1):
        card_info = pcpartpicker.lists.get_list("video-card", i)

        for card in card_info:
            
            #Create the primary key
            card_id = card['id']
            
            #Skip any cards without a price tag
            if card['price'] == '':
                print('No price found for card_id: {0}'.format(card_id))
                continue
            
            
            #Cleans the chipset_name data
            chipset_name = card['chipset']
            #chipset_text_banlist = [' 3GB', ' 6GB']
            #for item in chipset_text_banlist:
            #    if item in chipset_name:
            #        chipset_name = chipset_name.replace(item, '')
                    
            #Creates a row in the table 'chipsets' if chipset_name doesn't exist
            if chipset_name not in temp_chipsets_table['chipset_name'].values:
                try:
                    run_inserts(DB, insert_query_chipsets,[(chipset_name)])
                except Exception as e:
                    print('Failed to add into DB for {0}, {1}'.format(chipset_name, e))
                    pass
                    
                #Updates the temp_table
                temp_chipsets_table = run_query(DB, select_query_chipsets)
                    
            #Extracts the rest of the data
            chipset_id = temp_chipsets_table[temp_chipsets_table['chipset_name'] == chipset_name]['chipset_id'].values[0]
            card_name = card['name']
            series = card['series']
            memory = card['memory']
            core_clock = card['core-clock']
            ratings = card['ratings']
            
            #Unit conversions for 'memory' and 'core_clock'
            if 'MB' in memory:
                memory_in_GB = float(memory.split('MB')[0])/1000.00
            else: 
                memory_in_GB = memory.split('GB')[0]                
            
            if 'MHz' in core_clock:
                core_clock_in_GHz = float(core_clock.split('MHz')[0])/1000.00
            else: 
                core_clock_in_GHz = core_clock.split('GHz')[0] 
                  
            #Insert into the the table 'card_specs'
            try:
                run_inserts(DB, insert_query,(
                    card_id, card_name, series, int(chipset_id), float(memory_in_GB), float(core_clock_in_GHz), \
                    int(ratings), 
                    )
                )
            except Exception as e:
                print('Failed to add into DB for card_id: {0}, {1}'.format(card_id, e))
                pass
            
        #Provide stats for monitoring
        current_time = time.time()
        elapsed_time = current_time - start_time
        requests = i
        print('-------------------')
        print('Requests Completed: {}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
        print('Elapased Time: {} minutes'.format(elapsed_time/60))
        if requests == pages:
            print('Scrape Complete')
            break
        print('Pausing...')    
        time.sleep(random.uniform(sleep_min, sleep_max))   
        clear_output(wait = True)

# %%
scrape_card_list()
# Out:
# No price found for card_id: 9ZYWGX
# No price found for card_id: bpBrxr
# No price found for card_id: FdH48d
# Failed to add into DB for card_id: ZG4gXL, could not convert string to float: 'N/A'
# No price found for card_id: 2j4NnQ
# -------------------
# Requests Completed: 1; Frequency: 0.5757664902108259 requests/s
# Elapased Time: 0.028946920235951742 minutes
# Pausing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-9563e6a93476> in <module>()
# ----> 1 scrape_card_list()
#
# <ipython-input-4-3d2a6162cd37> in scrape_card_list(DB, sleep_min, sleep_max)
#      99             break
#     100         print('Pausing...')
# --> 101         time.sleep(random.uniform(sleep_min, sleep_max))
#     102         clear_output(wait = True)
#
# KeyboardInterrupt:

# %%
def scrape_card_page(DB = 'gpudata.db', prefix = '', history_days = 730, sleep_min = 5, sleep_max = 15):
    start_time = time.time()
    
    insert_query_prices = '''
    INSERT OR IGNORE INTO card_prices(
        card_id,
        merchant_id,
        datetime,
        price
    ) 
    VALUES (?, ?, ?, ?)
    '''

    insert_query_merchants = '''
    INSERT OR IGNORE INTO merchants(
        merchant_name
    ) 
    VALUES (?)
    '''
    
    update_query_card_specs = '''
    UPDATE card_specs
        SET 
            manufacturer=?,
            part_number=?,
            interface=?,
            memory_type=?,
            tdp_in_watts=?,
            fan=?,
            sli_support=?,
            crossfire_support=?,
            hdmi=?
        WHERE
            card_id=?
    '''
                 
    #Pulls merchants table from the database
    select_query_merchants = 'SELECT * FROM merchants'
    temp_merchants_table = run_query(DB, select_query_merchants)
    
    #Pulls card_ids table from the table gpu_specs
    pull_ids = 'SELECT card_id FROM card_specs'
    card_ids = run_query(DB, pull_ids)['card_id']
    
    for counter, card_id in enumerate(card_ids):
        
        #Makes a connection to the item webpage
        url = 'http://{0}pcpartpicker.com/product/{1}?history_days={2}'.format(prefix, card_id, history_days)
        headers ={"User-Agent": "gpudata web scraper for research, contact me at https://codingdisciple.com"}
        successful_connection = False
        connection_attempts = 0
        while not successful_connection:
            try:
                response = get(url=url, headers=headers)
                print('Connection successful.')
                successful_connection = True
            except:
                print('Connection unsuccessful, reconnecting...')
                connection_attempts += 1
                time.sleep(random.uniform(sleep_min, sleep_max))
                if connection_attempts == 10:
                    raise
                    
        html_soup = BeautifulSoup(response.text, 'html.parser')
        
        #Search for the raw data
        scripts = html_soup.findAll('script')
        for script in scripts:
            if 'phistmulti' in script.text:
                data = script.prettify().split('\n')
                for line in data:
                    if 'phistmulti' in line:
                        idx = line.index('[')
                        price_history = line[idx:-1]
                        price_data = loads(price_history)
                        break
        
        #Extracts price/merchant data
        for merchant in price_data:
            
            #Creates a row in the table 'merchants' if merchant_name doesn't exist
            merchant_name = merchant['label']
            if merchant_name != 'No price history is available for this time period.':
                if merchant_name not in temp_merchants_table['merchant_name'].values:
                    try:
                        run_inserts(DB, insert_query_merchants,[(merchant_name)])
                    except Exception as e:
                        print('Failed to add into DB for {0}, {1}'.format(merchant_name, e))
                        pass
                    
                    #Updates the temp_table
                    temp_merchants_table = run_query(DB, select_query_merchants)
                
            for date_points in merchant['data']:
                datetime = date_points[0]
                price = date_points[1]
                merchant_id = temp_merchants_table[temp_merchants_table['merchant_name'] == merchant_name]['merchant_id'].values[0]

                try:
                    run_inserts(DB, insert_query_prices,(
                        card_id, int(merchant_id), float(datetime/1000.00), float(price/100.00) 
                        )
                    )
                except Exception as e:
                    print('Failed to add into DB for card_id: {0}, datetime: {1}, merchant: {2}, {3}'.format(card_id, datetime, merchant_id, e))
                    pass
                
        #Updates the specs_table
        specs_block = html_soup.find('div', class_='specs block')
        
        #Shortens try/except loop code
        def find_specs(specs_block, keyword, failure_value):
            try:
                return specs_block.find(text=keyword).find_parent('h4').next_sibling.strip()
            except Exception as e:
                print(e)
                return failure_value
        
        manufacturer = find_specs(specs_block, 'Manufacturer', 'null')
        part_number = find_specs(specs_block, 'Part #', 'null')
        interface = find_specs(specs_block, 'Interface', 'null')
        memory_type = find_specs(specs_block, 'Memory Type', 'null')
        fan = find_specs(specs_block, 'Fan', 'null')
        sli_support = find_specs(specs_block, 'SLI Support', 'null')
        crossfire_support = find_specs(specs_block, 'CrossFire Support', 'null')
        hdmi = find_specs(specs_block, 'HDMI', 0)
        tdp = specs_block.find(text='TDP').find_parent('h4').next_sibling.strip()
        if ' Watts' in tdp:
            tdp_in_watts = tdp.replace(' Watts', '')
            
        try:
            run_inserts(DB, update_query_card_specs,(
                manufacturer, part_number, interface, memory_type, \
                int(tdp_in_watts), fan, sli_support, \
                crossfire_support, int(hdmi) ,card_id
                )
            )
        except Exception as e:
            print('Failed to update card_specs for card_id: {0}, {1}'.format(card_id, e))
            pass        

        #Provide stats for monitoring
        current_time = time.time()
        elapsed_time = current_time - start_time
        requests = counter + 1
        print('-------------------')
        print('Requests Completed: {}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
        print('Elapased Time: {} minutes'.format(elapsed_time/60))
        if requests == len(card_ids):
            print('Scrape Complete')
            break
        print('Pausing...')    
        time.sleep(random.uniform(sleep_min, sleep_max))   
        clear_output(wait = True)

# %%
scrape_card_page()
# Out:
# Connection successful.
# Failed to add into DB for card_id: zwbkcf, datetime: 1466076595000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1492889081000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1493665982000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1495307839000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1510184977000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1513297033000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515800363000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1516344396000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1521068094000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1466076595000, merchant: 5, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1495193281000, merchant: 5, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1529148595000, merchant: 5, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1466076595000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1494408489000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1494435523000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1494510322000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1494545416000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1494576985000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1494698516000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1495645347000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1495770431000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1495792907000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1495806398000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1495815411000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1496185248000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1496785440000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1497546244000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1499117484000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1499307358000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1499487386000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1499725729000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1499750866000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1499826786000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1499961614000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1499970653000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1500086752000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1502649003000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1502765132000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1502796774000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503080160000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503377145000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503399650000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503438259000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503485965000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503599795000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503617586000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503639948000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503657957000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503774019000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503971187000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1504020577000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1504140458000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1511905351000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1511952183000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1514550337000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1514695191000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1514947234000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1514961639000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1514972480000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1514983161000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515037189000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515069559000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515188369000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515206409000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515220917000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515228115000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515238914000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515455632000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515470030000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515484435000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515491689000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515498887000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515585165000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515765150000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1516042430000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1516218751000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1516430308000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1516451913000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1517635417000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1517642620000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1517660617000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1517955808000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1518006176000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1518291536000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1518507499000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1518521898000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1518676716000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1518683919000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1518698315000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1519163559000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1519239187000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1519260751000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1519267988000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1519278821000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1519293221000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1520624325000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1520879911000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1520897906000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1520923139000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1521027536000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1521196862000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1521888023000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1522754672000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1523383829000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1524248733000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1524309944000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1524641071000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1524673474000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1525112709000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1525389802000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1526754322000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1527615617000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1466076595000, merchant: 2, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1523426145000, merchant: 2, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1524203755000, merchant: 2, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1525067724000, merchant: 2, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1526796097000, merchant: 2, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1466076595000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1494542669000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1495115048000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1497930154000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1501303236000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1502257204000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503380366000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1513262010000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515681120000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1520087354000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1526190574000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1529148595000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1466076595000, merchant: 7, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1496741575000, merchant: 7, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1515450116000, merchant: 7, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1529148595000, merchant: 7, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1466076595000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1495804705000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1502730869000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1502990062000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503580439000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1503839631000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1505740370000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1508332278000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1510582195000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1513001303000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for card_id: zwbkcf, datetime: 1529148595000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# -------------------
# Requests Completed: 518; Frequency: 0.07516529344174847 requests/s
# Elapased Time: 114.85797417958578 minutes
# Scrape Complete

# %%
def scrape_benchmarks(DB = 'gpudata.db', sleep_min = 5, sleep_max = 15):
    start_time = time.time()
    
    insert_query_benchmarks = '''
    INSERT OR IGNORE INTO benchmarks(
        chipset_id,
        passmark_g3d,
        passmark_direct_compute
    ) 
    VALUES (?, ?, ?)
    '''
    
    #Get chipset_names from the database
    chipsets = run_query(DB, 'SELECT * FROM chipsets')
    db_names = chipsets['chipset_name']
    
    #Request information
    url_1 = 'https://www.videocardbenchmark.net/directCompute.html'
    url_2 = 'https://www.videocardbenchmark.net/GPU_mega_page.html'
    headers ={"User-Agent": "gpudata web scraper for research, contact me at https://codingdisciple.com"}
    successful_connection = False
    connection_attempts = 0
    
    #Makes a connection to the passmark webpage
    while not successful_connection:
        try:
            print ('Connecting to {}'.format(url_1))
            response_1 = get(url=url_1, headers=headers) 
            time.sleep(random.uniform(sleep_min, sleep_max))
            print('Pausing...')
            print ('Connecting to {}'.format(url_2))
            response_2 = get(url=url_2, headers=headers)
            print('Connection successful.')
            successful_connection = True    
        except:
            print('Connection unsuccessful, reconnecting...')
            connection_attempts += 1
            time.sleep(random.uniform(sleep_min, sleep_max))
            if connection_attempts == 10:
                raise
    
    #Create the soup objects
    html_soup1 = BeautifulSoup(response_1.text, 'html.parser')
    html_soup2 = BeautifulSoup(response_2.text, 'html.parser')    
    
    #Create a list of chipset names from passmark
    banlist = ('TITAN Xp COLLECTORS EDITION')
    html_soup2_body = html_soup2.find('tbody')
    passmark_names = [i.text for i in html_soup2_body.select('a[href^="video_lookup.php"]') if i.text not in banlist]
    
    #Log of names that could not be found in passmark_names or required regex searches
    no_names = []
    searched_names = []
    
    #Loop through the database chipset_names
    for db_id, chipset_name in enumerate(db_names):
        db_id += 1
        print('-'*len(chipset_name))
        print(chipset_name)
        print('-'*len(chipset_name))

        #Search for exact chipset_name matches:        
        name_found = False
        try:
            passmark_g3d = html_soup2.find(text=chipset_name).find_parent('tr').find_all('td')[2].text.replace(',', '').replace(' ', '')
            passmark_direct_compute = html_soup1.find(text=chipset_name).find_parent('tr').find('div').text.replace(',', '')
            name_found = True
            print('Adding to table "benchmarks", passmark_g3d: {}'.format(passmark_g3d))
            print('Adding to table "benchmarks", passmark_direct_compute: {}'.format(passmark_direct_compute))        
        except Exception as e:
            problematic_name = chipset_name
            print('Exact search failed, finding closest match')
        
        #Regex search chipset name in passmark_names
        if name_found == False:
            problematic_name = problematic_name.lower().split(' - ')[0]
            for actual_name in passmark_names:
                if re.findall(r'{}'.format(problematic_name), actual_name.lower()) != []:
                    print('Next match found: {}'.format(actual_name))
                    try:
                        passmark_g3d = html_soup2.find(text=actual_name).find_parent('tr').find_all('td')[2].text.replace(',', '').replace(' ', '')
                        passmark_direct_compute = html_soup1.find(text=actual_name).find_parent('tr').find('div').text.replace(',', '')
                        print('Adding to table "benchmarks", passmark_g3d: {}'.format(passmark_g3d))
                        print('Adding to table "benchmarks", passmark_direct_compute: {}'.format(passmark_direct_compute))                    
                        name_found = True
                        searched_names.append([chipset_name, actual_name])
                    except:
                        passmark_g3d = 'null'
                        passmark_direct_compute = 'null'
                    break
                
        #Add to the database            
        if name_found == True:
            try:
                run_inserts(DB, insert_query_benchmarks,(
                    int(db_id), int(passmark_g3d), int(passmark_direct_compute)
                    )
                )
                print('Successfully added to database')
            except Exception as e:
                print('Failed to add to benchmarks for chipset_id: {0}, {1}'.format(db_id, e))
                no_names.append(chipset_name)
                continue        
        else:
            print('Failed to add to benchmarks for chipset_id: {0}, {1}'.format(db_id, chipset_name))
            no_names.append(chipset_name)
    
    print('Scrape Summary:')
    print('---- Closest matches (chipset_name, passmark_name) ----')
    print(searched_names)
    print('---- No matches found (chipset_name) ----')
    print(no_names)

# %%
scrape_benchmarks()
# Out:
# Connecting to https://www.videocardbenchmark.net/directCompute.html
# Pausing...
# Connecting to https://www.videocardbenchmark.net/GPU_mega_page.html
# Connection successful.
# ----------------
# GeForce GTX 1060
# ----------------
# Adding to table "benchmarks", passmark_g3d: 8964
# Adding to table "benchmarks", passmark_direct_compute: 5018
# Successfully added to database
# -------------------
# GeForce GTX 1080 Ti
# -------------------
# Adding to table "benchmarks", passmark_g3d: 14028
# Adding to table "benchmarks", passmark_direct_compute: 9417
# Successfully added to database
# -------------------
# GeForce GTX 1050 Ti
# -------------------
# Adding to table "benchmarks", passmark_g3d: 5914
# Adding to table "benchmarks", passmark_direct_compute: 3250
# Successfully added to database
# -------------------
# GeForce GTX 1070 Ti
# -------------------
# Adding to table "benchmarks", passmark_g3d: 12222
# Adding to table "benchmarks", passmark_direct_compute: 7443
# Successfully added to database
# ----------------
# GeForce GTX 1080
# ----------------
# Adding to table "benchmarks", passmark_g3d: 12282
# Adding to table "benchmarks", passmark_direct_compute: 7966
# Successfully added to database
# ----------------
# GeForce GTX 1070
# ----------------
# Adding to table "benchmarks", passmark_g3d: 11162
# Adding to table "benchmarks", passmark_direct_compute: 6624
# Successfully added to database
# -------------
# Radeon RX 580
# -------------
# Adding to table "benchmarks", passmark_g3d: 8373
# Adding to table "benchmarks", passmark_direct_compute: 4288
# Successfully added to database
# ----------------
# GeForce GTX 1050
# ----------------
# Adding to table "benchmarks", passmark_g3d: 4566
# Adding to table "benchmarks", passmark_direct_compute: 2808
# Successfully added to database
# --------------------
# Radeon RX 560 - 1024
# --------------------
# Exact search failed, finding closest match
# Next match found: Radeon RX 560
# Adding to table "benchmarks", passmark_g3d: 4474
# Adding to table "benchmarks", passmark_direct_compute: 2460
# Successfully added to database
# ------------
# Quadro GP100
# ------------
# Adding to table "benchmarks", passmark_g3d: 11871
# Adding to table "benchmarks", passmark_direct_compute: 7109
# Successfully added to database
# ---------------
# GeForce GT 1030
# ---------------
# Adding to table "benchmarks", passmark_g3d: 2259
# Adding to table "benchmarks", passmark_direct_compute: 1638
# Successfully added to database
# --------
# Titan Xp
# --------
# Exact search failed, finding closest match
# Next match found: NVIDIA TITAN Xp
# Adding to table "benchmarks", passmark_g3d: 14305
# Adding to table "benchmarks", passmark_direct_compute: 9302
# Successfully added to database
# -------
# Titan V
# -------
# Exact search failed, finding closest match
# Next match found: TITAN V
# Adding to table "benchmarks", passmark_g3d: 14166
# Adding to table "benchmarks", passmark_direct_compute: 8801
# Successfully added to database
# -----------------
# Radeon RX VEGA 64
# -----------------
# Exact search failed, finding closest match
# Next match found: Radeon RX Vega 64
# Adding to table "benchmarks", passmark_g3d: 11632
# Adding to table "benchmarks", passmark_direct_compute: 7017
# Successfully added to database
# -------------
# Radeon RX 570
# -------------
# Adding to table "benchmarks", passmark_g3d: 6817
# Adding to table "benchmarks", passmark_direct_compute: 3225
# Successfully added to database
# --------------
# Radeon HD 4350
# --------------
# Exact search failed, finding closest match
# Next match found: Mobility Radeon HD 4350
# Failed to add to benchmarks for chipset_id: 16, Radeon HD 4350
# --------------
# GeForce GT 710
# --------------
# Adding to table "benchmarks", passmark_g3d: 678
# Adding to table "benchmarks", passmark_direct_compute: 566
# Successfully added to database
# ---------------
# GeForce GTX 970
# ---------------
# Adding to table "benchmarks", passmark_g3d: 8590
# Adding to table "benchmarks", passmark_direct_compute: 4407
# Successfully added to database
# ------------
# Quadro P6000
# ------------
# Adding to table "benchmarks", passmark_g3d: 13657
# Adding to table "benchmarks", passmark_direct_compute: 8536
# Successfully added to database
# -----------------
# Radeon RX VEGA 56
# -----------------
# Exact search failed, finding closest match
# Next match found: Radeon RX Vega 56
# Adding to table "benchmarks", passmark_g3d: 11167
# Adding to table "benchmarks", passmark_direct_compute: 6455
# Successfully added to database
# -------------------
# Radeon RX 560 - 896
# -------------------
# Exact search failed, finding closest match
# Next match found: Radeon RX 560
# Adding to table "benchmarks", passmark_g3d: 4474
# Adding to table "benchmarks", passmark_direct_compute: 2460
# Successfully added to database
# --------------
# Radeon HD 6450
# --------------
# Adding to table "benchmarks", passmark_g3d: 278
# Adding to table "benchmarks", passmark_direct_compute: 186
# Successfully added to database
# ------------
# Quadro P4000
# ------------
# Adding to table "benchmarks", passmark_g3d: 10483
# Adding to table "benchmarks", passmark_direct_compute: 5331
# Successfully added to database
# -------------------
# Radeon RX 550 - 512
# -------------------
# Exact search failed, finding closest match
# Next match found: Radeon RX 550
# Adding to table "benchmarks", passmark_g3d: 3476
# Adding to table "benchmarks", passmark_direct_compute: 1670
# Successfully added to database
# ---------------------
# Vega Frontier Edition
# ---------------------
# Exact search failed, finding closest match
# Next match found: Radeon Vega Frontier Edition
# Adding to table "benchmarks", passmark_g3d: 11457
# Adding to table "benchmarks", passmark_direct_compute: 6921
# Successfully added to database
# --------------
# GeForce GT 730
# --------------
# Adding to table "benchmarks", passmark_g3d: 924
# Adding to table "benchmarks", passmark_direct_compute: 682
# Successfully added to database
# ------------
# Quadro M6000
# ------------
# Adding to table "benchmarks", passmark_g3d: 9295
# Adding to table "benchmarks", passmark_direct_compute: 5345
# Successfully added to database
# -------------
# FirePro W9100
# -------------
# Adding to table "benchmarks", passmark_g3d: 7136
# Adding to table "benchmarks", passmark_direct_compute: 2996
# Successfully added to database
# ------------------
# Radeon Pro WX 5100
# ------------------
# Adding to table "benchmarks", passmark_g3d: 5507
# Adding to table "benchmarks", passmark_direct_compute: 2893
# Successfully added to database
# -------------
# Radeon R9 390
# -------------
# Adding to table "benchmarks", passmark_g3d: 8077
# Adding to table "benchmarks", passmark_direct_compute: 3963
# Successfully added to database
# ---------------
# GeForce GTX 950
# ---------------
# Adding to table "benchmarks", passmark_g3d: 5212
# Adding to table "benchmarks", passmark_direct_compute: 2530
# Successfully added to database
# ------------------
# GeForce GTX 750 Ti
# ------------------
# Adding to table "benchmarks", passmark_g3d: 3726
# Adding to table "benchmarks", passmark_direct_compute: 1873
# Successfully added to database
# ------------
# Quadro P2000
# ------------
# Adding to table "benchmarks", passmark_g3d: 8208
# Adding to table "benchmarks", passmark_direct_compute: 3786
# Successfully added to database
# -------------------
# Radeon RX 550 - 640
# -------------------
# Exact search failed, finding closest match
# Next match found: Radeon RX 550
# Adding to table "benchmarks", passmark_g3d: 3476
# Adding to table "benchmarks", passmark_direct_compute: 1670
# Successfully added to database
# -------------
# Radeon R5 230
# -------------
# Adding to table "benchmarks", passmark_g3d: 233
# Adding to table "benchmarks", passmark_direct_compute: 264
# Successfully added to database
# ------------------
# Radeon Pro WX 4100
# ------------------
# Adding to table "benchmarks", passmark_g3d: 3968
# Adding to table "benchmarks", passmark_direct_compute: 2594
# Successfully added to database
# -------------
# Radeon R9 380
# -------------
# Adding to table "benchmarks", passmark_g3d: 6100
# Adding to table "benchmarks", passmark_direct_compute: 2976
# Successfully added to database
# ------------
# Quadro P5000
# ------------
# Adding to table "benchmarks", passmark_g3d: 10256
# Adding to table "benchmarks", passmark_direct_compute: 6612
# Successfully added to database
# ------------------
# Radeon Pro WX 7100
# ------------------
# Adding to table "benchmarks", passmark_g3d: 7786
# Adding to table "benchmarks", passmark_direct_compute: 4030
# Successfully added to database
# --------------
# Radeon R9 270X
# --------------
# Adding to table "benchmarks", passmark_g3d: 4681
# Adding to table "benchmarks", passmark_direct_compute: 2566
# Successfully added to database
# ---------------
# GeForce GTX 980
# ---------------
# Adding to table "benchmarks", passmark_g3d: 9596
# Adding to table "benchmarks", passmark_direct_compute: 5153
# Successfully added to database
# ------------
# Quadro P1000
# ------------
# Adding to table "benchmarks", passmark_g3d: 4994
# Adding to table "benchmarks", passmark_direct_compute: 2568
# Successfully added to database
# ---------------
# GeForce GTX 960
# ---------------
# Adding to table "benchmarks", passmark_g3d: 5804
# Adding to table "benchmarks", passmark_direct_compute: 3083
# Successfully added to database
# -------------
# FirePro V5800
# -------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 44, FirePro V5800
# --------------
# Radeon HD 5450
# --------------
# Adding to table "benchmarks", passmark_g3d: 231
# Adding to table "benchmarks", passmark_direct_compute: 83
# Successfully added to database
# ----------------------
# Radeon Pro Duo Polaris
# ----------------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 46, Radeon Pro Duo Polaris
# ------------------
# Radeon Pro WX 3100
# ------------------
# Adding to table "benchmarks", passmark_g3d: 3591
# Adding to table "benchmarks", passmark_direct_compute: 2089
# Successfully added to database
# ---------------
# GeForce 8400 GS
# ---------------
# Adding to table "benchmarks", passmark_g3d: 113
# Adding to table "benchmarks", passmark_direct_compute: 58
# Successfully added to database
# -------------
# Radeon R7 250
# -------------
# Adding to table "benchmarks", passmark_g3d: 1407
# Adding to table "benchmarks", passmark_direct_compute: 939
# Successfully added to database
# --------------
# Radeon R9 280X
# --------------
# Adding to table "benchmarks", passmark_g3d: 5844
# Adding to table "benchmarks", passmark_direct_compute: 3643
# Successfully added to database
# -------------
# Radeon RX 460
# -------------
# Adding to table "benchmarks", passmark_g3d: 4337
# Adding to table "benchmarks", passmark_direct_compute: 2489
# Successfully added to database
# -----------
# Quadro P600
# -----------
# Adding to table "benchmarks", passmark_g3d: 3099
# Adding to table "benchmarks", passmark_direct_compute: 1891
# Successfully added to database
# --------------
# Radeon R9 Fury
# --------------
# Adding to table "benchmarks", passmark_g3d: 9224
# Adding to table "benchmarks", passmark_direct_compute: 5136
# Successfully added to database
# ---------------
# GeForce GTX 660
# ---------------
# Adding to table "benchmarks", passmark_g3d: 4127
# Adding to table "benchmarks", passmark_direct_compute: 1982
# Successfully added to database
# ------------
# Quadro M4000
# ------------
# Adding to table "benchmarks", passmark_g3d: 6696
# Adding to table "benchmarks", passmark_direct_compute: 2762
# Successfully added to database
# --------------
# Radeon HD 7750
# --------------
# Adding to table "benchmarks", passmark_g3d: 1700
# Adding to table "benchmarks", passmark_direct_compute: 1051
# Successfully added to database
# -----------
# Quadro 4000
# -----------
# Adding to table "benchmarks", passmark_g3d: 2025
# Adding to table "benchmarks", passmark_direct_compute: 710
# Successfully added to database
# ------------------
# GeForce GTX 980 Ti
# ------------------
# Adding to table "benchmarks", passmark_g3d: 11341
# Adding to table "benchmarks", passmark_direct_compute: 6402
# Successfully added to database
# -------------
# Radeon R7 370
# -------------
# Adding to table "benchmarks", passmark_g3d: 4663
# Adding to table "benchmarks", passmark_direct_compute: 2656
# Successfully added to database
# ------------
# FirePro 2270
# ------------
# Adding to table "benchmarks", passmark_g3d: 226
# Adding to table "benchmarks", passmark_direct_compute: 74
# Successfully added to database
# -----------
# Quadro P400
# -----------
# Adding to table "benchmarks", passmark_g3d: 1736
# Adding to table "benchmarks", passmark_direct_compute: 967
# Successfully added to database
# -----------
# Quadro 6000
# -----------
# Adding to table "benchmarks", passmark_g3d: 3505
# Adding to table "benchmarks", passmark_direct_compute: 1236
# Successfully added to database
# --------------
# Quadro NVS 295
# --------------
# Exact search failed, finding closest match
# Next match found: Quadro NVS 295
# Failed to add to benchmarks for chipset_id: 63, Quadro NVS 295
# ------------
# Quadro K2200
# ------------
# Adding to table "benchmarks", passmark_g3d: 3560
# Adding to table "benchmarks", passmark_direct_compute: 1734
# Successfully added to database
# ------------
# Quadro K4000
# ------------
# Adding to table "benchmarks", passmark_g3d: 2882
# Adding to table "benchmarks", passmark_direct_compute: 1300
# Successfully added to database
# ---------------
# GeForce GTX 570
# ---------------
# Adding to table "benchmarks", passmark_g3d: 4418
# Adding to table "benchmarks", passmark_direct_compute: 1693
# Successfully added to database
# -------------
# FirePro W9000
# -------------
# Adding to table "benchmarks", passmark_g3d: 5394
# Adding to table "benchmarks", passmark_direct_compute: 3266
# Successfully added to database
# -------------
# Radeon R9 290
# -------------
# Exact search failed, finding closest match
# Next match found: Radeon R9 290 / 390
# Adding to table "benchmarks", passmark_g3d: 7106
# Adding to table "benchmarks", passmark_direct_compute: 3289
# Successfully added to database
# --------------
# Radeon HD 7970
# --------------
# Exact search failed, finding closest match
# Next match found: Radeon HD 7970 / R9 280X
# Adding to table "benchmarks", passmark_g3d: 5247
# Adding to table "benchmarks", passmark_direct_compute: 3167
# Successfully added to database
# ---------------
# GeForce 9400 GT
# ---------------
# Exact search failed, finding closest match
# Next match found: GeForce 9400 GT
# Failed to add to benchmarks for chipset_id: 70, GeForce 9400 GT
# -----------
# Quadro K600
# -----------
# Adding to table "benchmarks", passmark_g3d: 827
# Adding to table "benchmarks", passmark_direct_compute: 412
# Successfully added to database
# ---------------
# GeForce GTX 650
# ---------------
# Adding to table "benchmarks", passmark_g3d: 1832
# Adding to table "benchmarks", passmark_direct_compute: 851
# Successfully added to database
# ------------------
# Radeon Pro WX 9100
# ------------------
# Adding to table "benchmarks", passmark_g3d: 10972
# Adding to table "benchmarks", passmark_direct_compute: 6486
# Successfully added to database
# -----------
# GeForce 210
# -----------
# Adding to table "benchmarks", passmark_g3d: 174
# Adding to table "benchmarks", passmark_direct_compute: 516
# Successfully added to database
# ------------------
# Radeon Pro WX 2100
# ------------------
# Adding to table "benchmarks", passmark_g3d: 1836
# Adding to table "benchmarks", passmark_direct_compute: 1741
# Successfully added to database
# -------------
# Radeon R7 240
# -------------
# Adding to table "benchmarks", passmark_g3d: 976
# Adding to table "benchmarks", passmark_direct_compute: 662
# Successfully added to database
# -----------
# Quadro K620
# -----------
# Adding to table "benchmarks", passmark_g3d: 2326
# Adding to table "benchmarks", passmark_direct_compute: 1154
# Successfully added to database
# -----------
# Radeon 9550
# -----------
# Exact search failed, finding closest match
# Next match found: RADEON 9550
# Failed to add to benchmarks for chipset_id: 78, Radeon 9550
# ----------
# Quadro 400
# ----------
# Exact search failed, finding closest match
# Next match found: Quadro 400
# Failed to add to benchmarks for chipset_id: 79, Quadro 400
# -------------
# FirePro W8000
# -------------
# Adding to table "benchmarks", passmark_g3d: 4418
# Adding to table "benchmarks", passmark_direct_compute: 2706
# Successfully added to database
# ------------
# FireGL V7300
# ------------
# Exact search failed, finding closest match
# Next match found: FireGL V7300
# Failed to add to benchmarks for chipset_id: 81, FireGL V7300
# --------------
# Radeon HD 7950
# --------------
# Exact search failed, finding closest match
# Next match found: Radeon HD 7950 / R9 280
# Adding to table "benchmarks", passmark_g3d: 4764
# Adding to table "benchmarks", passmark_direct_compute: 2725
# Successfully added to database
# ------------------
# GeForce GTX 560 Ti
# ------------------
# Adding to table "benchmarks", passmark_g3d: 3535
# Adding to table "benchmarks", passmark_direct_compute: 1461
# Successfully added to database
# --------------
# Radeon HD 3450
# --------------
# Exact search failed, finding closest match
# Next match found: Mobility Radeon HD 3450
# Failed to add to benchmarks for chipset_id: 84, Radeon HD 3450
# -------------
# FirePro V3800
# -------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 85, FirePro V3800
# --------------
# Radeon HD 6950
# --------------
# Adding to table "benchmarks", passmark_g3d: 3207
# Adding to table "benchmarks", passmark_direct_compute: 1273
# Successfully added to database
# -------
# NVS 810
# -------
# Exact search failed, finding closest match
# Next match found: NVS 810
# Failed to add to benchmarks for chipset_id: 87, NVS 810
# --------------
# GeForce GT 430
# --------------
# Adding to table "benchmarks", passmark_g3d: 659
# Adding to table "benchmarks", passmark_direct_compute: 362
# Successfully added to database
# ------------
# Quadro M5000
# ------------
# Adding to table "benchmarks", passmark_g3d: 8468
# Adding to table "benchmarks", passmark_direct_compute: 4232
# Successfully added to database
# -------------
# Radeon R7 360
# -------------
# Adding to table "benchmarks", passmark_g3d: 3303
# Adding to table "benchmarks", passmark_direct_compute: 1814
# Successfully added to database
# --------------
# Quadro NVS 420
# --------------
# Exact search failed, finding closest match
# Next match found: Quadro NVS 420
# Failed to add to benchmarks for chipset_id: 91, Quadro NVS 420
# ------------
# Quadro K1200
# ------------
# Adding to table "benchmarks", passmark_g3d: 3034
# Adding to table "benchmarks", passmark_direct_compute: 1532
# Successfully added to database
# ------------
# Quadro M2000
# ------------
# Adding to table "benchmarks", passmark_g3d: 4307
# Adding to table "benchmarks", passmark_direct_compute: 2346
# Successfully added to database
# -------------
# FirePro V3900
# -------------
# Adding to table "benchmarks", passmark_g3d: 870
# Adding to table "benchmarks", passmark_direct_compute: 469
# Successfully added to database
# --------------
# Quadro NVS 450
# --------------
# Exact search failed, finding closest match
# Next match found: Quadro NVS 450
# Failed to add to benchmarks for chipset_id: 95, Quadro NVS 450
# -------------
# FirePro S7000
# -------------
# Adding to table "benchmarks", passmark_g3d: 4166
# Adding to table "benchmarks", passmark_direct_compute: 2223
# Successfully added to database
# -------------
# FirePro W7100
# -------------
# Adding to table "benchmarks", passmark_g3d: 5373
# Adding to table "benchmarks", passmark_direct_compute: 2507
# Successfully added to database
# --------------
# Radeon HD 7870
# --------------
# Adding to table "benchmarks", passmark_g3d: 4366
# Adding to table "benchmarks", passmark_direct_compute: 2392
# Successfully added to database
# --------------
# GeForce GT 640
# --------------
# Adding to table "benchmarks", passmark_g3d: 1281
# Adding to table "benchmarks", passmark_direct_compute: 710
# Successfully added to database
# ------------------
# GeForce GTX 650 Ti
# ------------------
# Adding to table "benchmarks", passmark_g3d: 2658
# Adding to table "benchmarks", passmark_direct_compute: 1429
# Successfully added to database
# -----------
# Quadro K420
# -----------
# Adding to table "benchmarks", passmark_g3d: 837
# Adding to table "benchmarks", passmark_direct_compute: 465
# Successfully added to database
# -------------
# FirePro V8800
# -------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 102, FirePro V8800
# ---------------
# GeForce GTX 680
# ---------------
# Adding to table "benchmarks", passmark_g3d: 5678
# Adding to table "benchmarks", passmark_direct_compute: 2952
# Successfully added to database
# ------------
# Quadro K6000
# ------------
# Adding to table "benchmarks", passmark_g3d: 7644
# Adding to table "benchmarks", passmark_direct_compute: 3979
# Successfully added to database
# --------------------------
# Radeon HD 7970 GHz Edition
# --------------------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 105, Radeon HD 7970 GHz Edition
# -------------
# FirePro R5000
# -------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 106, FirePro R5000
# --------------
# GeForce GT 630
# --------------
# Adding to table "benchmarks", passmark_g3d: 746
# Adding to table "benchmarks", passmark_direct_compute: 433
# Successfully added to database
# ------------
# Quadro K5000
# ------------
# Adding to table "benchmarks", passmark_g3d: 4021
# Adding to table "benchmarks", passmark_direct_compute: 1913
# Successfully added to database
# ------------
# Quadro K4200
# ------------
# Adding to table "benchmarks", passmark_g3d: 4476
# Adding to table "benchmarks", passmark_direct_compute: 2039
# Successfully added to database
# ------------
# Quadro K2000
# ------------
# Adding to table "benchmarks", passmark_g3d: 1713
# Adding to table "benchmarks", passmark_direct_compute: 819
# Successfully added to database
# --------------
# Radeon HD 6770
# --------------
# Adding to table "benchmarks", passmark_g3d: 1678
# Adding to table "benchmarks", passmark_direct_compute: 815
# Successfully added to database
# --------------
# GeForce GT 720
# --------------
# Adding to table "benchmarks", passmark_g3d: 717
# Adding to table "benchmarks", passmark_direct_compute: 524
# Successfully added to database
# --------------
# Radeon HD 4850
# --------------
# Exact search failed, finding closest match
# Next match found: Mobility Radeon HD 4850
# Failed to add to benchmarks for chipset_id: 113, Radeon HD 4850
# ------------
# Quadro 2000D
# ------------
# Adding to table "benchmarks", passmark_g3d: 1278
# Adding to table "benchmarks", passmark_direct_compute: 654
# Successfully added to database
# ------------
# FirePro 2450
# ------------
# Exact search failed, finding closest match
# Next match found: FirePro 2450
# Failed to add to benchmarks for chipset_id: 115, FirePro 2450
# -------------
# FirePro W7000
# -------------
# Adding to table "benchmarks", passmark_g3d: 4252
# Adding to table "benchmarks", passmark_direct_compute: 2371
# Successfully added to database
# --------------
# Radeon HD 6870
# --------------
# Adding to table "benchmarks", passmark_g3d: 2606
# Adding to table "benchmarks", passmark_direct_compute: 1169
# Successfully added to database
# --------------
# Radeon HD 4670
# --------------
# Exact search failed, finding closest match
# Next match found: Mobility Radeon HD 4670
# Failed to add to benchmarks for chipset_id: 118, Radeon HD 4670
# --------------
# Radeon HD 7770
# --------------
# Adding to table "benchmarks", passmark_g3d: 2213
# Adding to table "benchmarks", passmark_direct_compute: 1436
# Successfully added to database
# --------------
# Radeon HD 5670
# --------------
# Adding to table "benchmarks", passmark_g3d: 1080
# Adding to table "benchmarks", passmark_direct_compute: 453
# Successfully added to database
# --------------
# GeForce GT 610
# --------------
# Adding to table "benchmarks", passmark_g3d: 351
# Adding to table "benchmarks", passmark_direct_compute: 228
# Successfully added to database
# --------------
# Radeon HD 6670
# --------------
# Adding to table "benchmarks", passmark_g3d: 1058
# Adding to table "benchmarks", passmark_direct_compute: 524
# Successfully added to database
# -------------
# Radeon RX 480
# -------------
# Adding to table "benchmarks", passmark_g3d: 8118
# Adding to table "benchmarks", passmark_direct_compute: 4397
# Successfully added to database
# -------------
# Radeon RX 470
# -------------
# Adding to table "benchmarks", passmark_g3d: 7472
# Adding to table "benchmarks", passmark_direct_compute: 3887
# Successfully added to database
# ---------------
# GeForce GTX 670
# ---------------
# Adding to table "benchmarks", passmark_g3d: 5372
# Adding to table "benchmarks", passmark_direct_compute: 2605
# Successfully added to database
# -------------
# Radeon R9 285
# -------------
# Exact search failed, finding closest match
# Next match found: Radeon R9 285 / 380
# Adding to table "benchmarks", passmark_g3d: 5553
# Adding to table "benchmarks", passmark_direct_compute: 2445
# Successfully added to database
# -------------
# FirePro S9150
# -------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 127, FirePro S9150
# -------------
# FirePro W5100
# -------------
# Adding to table "benchmarks", passmark_g3d: 3001
# Adding to table "benchmarks", passmark_direct_compute: 1706
# Successfully added to database
# --------------
# Radeon HD 5770
# --------------
# Adding to table "benchmarks", passmark_g3d: 1706
# Adding to table "benchmarks", passmark_direct_compute: 821
# Successfully added to database
# -------------
# Quadro K2000D
# -------------
# Adding to table "benchmarks", passmark_g3d: 1672
# Adding to table "benchmarks", passmark_direct_compute: 795
# Successfully added to database
# --------------------------
# Radeon HD 7870 GHz Edition
# --------------------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 131, Radeon HD 7870 GHz Edition
# -------------
# FirePro S9050
# -------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 132, FirePro S9050
# ------------
# Quadro K5200
# ------------
# Adding to table "benchmarks", passmark_g3d: 6136
# Adding to table "benchmarks", passmark_direct_compute: 2851
# Successfully added to database
# --------------
# Radeon HD 6850
# --------------
# Adding to table "benchmarks", passmark_g3d: 2280
# Adding to table "benchmarks", passmark_direct_compute: 925
# Successfully added to database
# ---------------
# GeForce 9500 GT
# ---------------
# Adding to table "benchmarks", passmark_g3d: 275
# Adding to table "benchmarks", passmark_direct_compute: 51
# Successfully added to database
# ---------------
# GeForce GTX 470
# ---------------
# Adding to table "benchmarks", passmark_g3d: 3602
# Adding to table "benchmarks", passmark_direct_compute: 1353
# Successfully added to database
# --------------
# Radeon HD 5750
# --------------
# Adding to table "benchmarks", passmark_g3d: 1437
# Adding to table "benchmarks", passmark_direct_compute: 674
# Successfully added to database
# ------------
# FirePro 2460
# ------------
# Adding to table "benchmarks", passmark_g3d: 215
# Adding to table "benchmarks", passmark_direct_compute: 59
# Successfully added to database
# --------------
# Radeon HD 6970
# --------------
# Adding to table "benchmarks", passmark_g3d: 3514
# Adding to table "benchmarks", passmark_direct_compute: 1416
# Successfully added to database
# --------------
# GeForce GT 620
# --------------
# Adding to table "benchmarks", passmark_g3d: 431
# Adding to table "benchmarks", passmark_direct_compute: 280
# Successfully added to database
# --------------
# GeForce GT 440
# --------------
# Adding to table "benchmarks", passmark_g3d: 841
# Adding to table "benchmarks", passmark_direct_compute: 422
# Successfully added to database
# --------------
# FirePro RG220A
# --------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 142, FirePro RG220A
# --------------
# Radeon HD 5570
# --------------
# Adding to table "benchmarks", passmark_g3d: 713
# Adding to table "benchmarks", passmark_direct_compute: 354
# Successfully added to database
# -------------
# FirePro W5000
# -------------
# Adding to table "benchmarks", passmark_g3d: 3059
# Adding to table "benchmarks", passmark_direct_compute: 1437
# Successfully added to database
# --------------
# Quadro FX 1800
# --------------
# Exact search failed, finding closest match
# Next match found: Quadro FX 1800
# Failed to add to benchmarks for chipset_id: 145, Quadro FX 1800
# ---------------
# GeForce 7200 GS
# ---------------
# Exact search failed, finding closest match
# Failed to add to benchmarks for chipset_id: 146, GeForce 7200 GS
# ----------
# Quadro 410
# ----------
# Adding to table "benchmarks", passmark_g3d: 419
# Adding to table "benchmarks", passmark_direct_compute: 355
# Successfully added to database
# ------------------
# GeForce GTX 780 Ti
# ------------------
# Adding to table "benchmarks", passmark_g3d: 8892
# Adding to table "benchmarks", passmark_direct_compute: 4701
# Successfully added to database
# ---------------
# GeForce GTX 460
# ---------------
# Adding to table "benchmarks", passmark_g3d: 2655
# Adding to table "benchmarks", passmark_direct_compute: 1109
# Successfully added to database
# -------------
# FirePro V7900
# -------------
# Adding to table "benchmarks", passmark_g3d: 2717
# Adding to table "benchmarks", passmark_direct_compute: 914
# Successfully added to database
# Scrape Summary:
# ---- Closest matches (chipset_name, passmark_name) ----
# [['Radeon RX 560 - 1024', 'Radeon RX 560'], ['Titan Xp', 'NVIDIA TITAN Xp'], ['Titan V', 'TITAN V'], ['Radeon RX VEGA 64', 'Radeon RX Vega 64'], ['Radeon RX VEGA 56', 'Radeon RX Vega 56'], ['Radeon RX 560 - 896', 'Radeon RX 560'], ['Radeon RX 550 - 512', 'Radeon RX 550'], ['Vega Frontier Edition', 'Radeon Vega Frontier Edition'], ['Radeon RX 550 - 640', 'Radeon RX 550'], ['Radeon R9 290', 'Radeon R9 290 / 390'], ['Radeon HD 7970', 'Radeon HD 7970 / R9 280X'], ['Radeon HD 7950', 'Radeon HD 7950 / R9 280'], ['Radeon R9 285', 'Radeon R9 285 / 380']]
# ---- No matches found (chipset_name) ----
# ['Radeon HD 4350', 'FirePro V5800', 'Radeon Pro Duo Polaris', 'Quadro NVS 295', 'GeForce 9400 GT', 'Radeon 9550', 'Quadro 400', 'FireGL V7300', 'Radeon HD 3450', 'FirePro V3800', 'NVS 810', 'Quadro NVS 420', 'Quadro NVS 450', 'FirePro V8800', 'Radeon HD 7970 GHz Edition', 'FirePro R5000', 'Radeon HD 4850', 'FirePro 2450', 'Radeon HD 4670', 'FirePro S9150', 'Radeon HD 7870 GHz Edition', 'FirePro S9050', 'FirePro RG220A', 'Quadro FX 1800', 'GeForce 7200 GS']

# %%
url = 'https://www.videocardbenchmark.net/directCompute.html'
headers ={"User-Agent": "gpudata web scraper for research, contact me at https://codingdisciple.com"}
response = get(url=url, headers=headers)
html_soup1 = BeautifulSoup(response.text, 'html.parser')

# %%
passmark_direct_compute = html_soup1.find(text='GeForce GTX 1080 Ti').find_parent('tr').find('div').text.replace(',', '')
int(passmark_direct_compute)

# %%
url = 'https://www.videocardbenchmark.net/GPU_mega_page.html'
headers ={"User-Agent": "gpudata web scraper for research, contact me at https://codingdisciple.com"}
response = get(url=url, headers=headers)
html_soup2 = BeautifulSoup(response.text, 'html.parser')

# %%
passmark_g3d = html_soup2.find(text='GeForce GTX 1080 Ti').find_parent('tr').find('div').text.replace(',', '')
int(passmark_g3d)
# Out:
# 14018

# %%
banlist = ('TITAN Xp COLLECTORS EDITION')
html_soup2_body = html_soup2.find('tbody')
passmark_names = [i.text for i in html_soup2_body.select('a[href^="video_lookup.php"]') if i.text not in banlist]

# %%
for actual_name in passmark_names:
    finding = re.findall(r'{}'.format('TITAN Xp'.lower()), actual_name.lower())
    if finding != []:
        print(finding)
# Out:
# ['titan xp']
