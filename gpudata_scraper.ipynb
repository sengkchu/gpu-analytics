# %%
import sqlite3
from requests import get
from bs4 import BeautifulSoup
import time
import random
import pandas as pd
import re
import math
from json import loads
from IPython.core.display import clear_output
from PCPartPicker_API import pcpartpicker

# %%
#Interface with SQL
def run_query(DB, q):
    with sqlite3.connect(DB) as conn:
        return pd.read_sql(q,conn)

def run_command(DB, c):
    with sqlite3.connect(DB) as conn:
        conn.execute('PRAGMA foreign_keys = ON;')
        conn.isolation_level = None
        conn.execute(c)
        
def run_inserts(DB, c, values):
    with sqlite3.connect(DB) as conn:
        conn.execute('PRAGMA foreign_keys = ON;')
        conn.isolation_level = None
        conn.execute(c, values)

# %%
def scrape_gpu_specs(DB = 'gpudata.db', sleep_min = 5, sleep_max = 15):
    start_time = time.time()
    pages = pcpartpicker.lists.total_pages("video-card")
    
    insert_query = '''
    INSERT OR IGNORE INTO gpu_specs(
        item_id,
        name,
        series,
        chipset,
        memory,
        core_clock,
        ratings
    ) 
    VALUES (?, ?, ?, ?, ?, ?, ?)
    '''
    
    for i in range(1, pages+1):
        gpu_info = pcpartpicker.lists.get_list("video-card", i)

        for gpu in gpu_info:
            item_id = gpu['id']
            name = gpu['name']
            series = gpu['series']
            chipset = gpu['chipset']
            memory = gpu['memory']
            core_clock = gpu['core-clock']
            ratings = gpu['ratings']
            if gpu['price'] == '':
                print('No price found for item_id: {0}'.format(item_id))
                continue
                
            try:
                run_inserts(DB, insert_query,(
                    item_id, name, series, chipset, memory, core_clock, \
                    int(ratings), 
                    )
                )
            except Exception as e:
                print('Failed to add into DB for item_id: {0}, {1}'.format(item_id, e))
                pass
            
        #Provide stats for monitoring
        current_time = time.time()
        elapsed_time = current_time - start_time
        requests = i
        print('-------------------')
        print('Requests Completed: {}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
        print('Elapased Time: {} minutes'.format(elapsed_time/60))
        if requests == pages:
            print('Scrape Complete')
            break
        print('Pausing...')    
        time.sleep(random.uniform(sleep_min, sleep_max))   
        clear_output(wait = True)

# %%
def scrape_gpu_prices(DB = 'gpudata.db', prefix = '', history_days = 730, sleep_min = 5, sleep_max = 15):
    start_time = time.time()
    
    insert_query_prices = '''
    INSERT OR IGNORE INTO gpu_prices(
        item_id,
        merchant_id,
        datetime,
        price
    ) 
    VALUES (?, ?, ?, ?)
    '''

    insert_query_merchants = '''
    INSERT OR IGNORE INTO merchants(
        merchant_name
    ) 
    VALUES (?)
    '''
    
    #Pulls merchants table from the database
    select_query_merchants = 'SELECT * FROM merchants'
    temp_merchants_table = run_query(DB, select_query_merchants)
    
    #Pulls item_id table from the table gpu_specs
    pull_ids = 'SELECT item_id FROM gpu_specs'
    item_ids = run_query(DB, pull_ids)['item_id']
    
    for counter, item_id in enumerate(item_ids):
        
        #Makes a connection to the item webpage
        url = 'http://{0}pcpartpicker.com/product/{1}?history_days={2}'.format(prefix, item_id, history_days)
        headers ={"User-Agent": "gpudata web scraper for research, contact me at https://codingdisciple.com"}
        successful_connection = False
        connection_attempts = 0
        while not successful_connection:
            try:
                response = get(url=url, headers=headers)
                print('Connection successful.')
                successful_connection = True
            except:
                print('Connection unsuccessful, reconnecting...')
                connection_attempts += 1
                time.sleep(random.uniform(sleep_min, sleep_max))
                if connection_attempts == 10:
                    raise
                    
        html_soup = BeautifulSoup(response.text, 'html.parser')
        
        #Search for the raw data
        scripts = html_soup.findAll('script')
        for script in scripts:
            if 'phistmulti' in script.text:
                data = script.prettify().split('\n')
                for line in data:
                    if 'phistmulti' in line:
                        idx = line.index('[')
                        price_history = line[idx:-1]
                        price_data = loads(price_history)
                        break
        
        #Extracts price/merchant data
        for merchant in price_data:
            
            #Creates a row in the table 'merchants' if merchant_name doesn't exist
            merchant_name = merchant['label']
            if merchant_name != 'No price history is available for this time period.':
                if merchant_name not in temp_merchants_table['merchant_name'].values:
                    try:
                        run_inserts(DB, insert_query_merchants,[(merchant_name)])
                    except Exception as e:
                        print('Failed to add into DB for {0}, {1}'.format(merchant_name, e))
                        pass
                    
                    #Updates the temp_table
                    temp_merchants_table = run_query(DB, select_query_merchants)
                
            for date_points in merchant['data']:
                datetime = date_points[0]
                price = date_points[1]
                merchant_id = temp_merchants_table[temp_merchants_table['merchant_name'] == merchant_name]['merchant_id'].values[0]

                try:
                    run_inserts(DB, insert_query_prices,(
                        item_id, int(merchant_id), float(datetime/1000.00), float(price/100.00) 
                        )
                    )
                except Exception as e:
                    print('Failed to add into DB for item_id: {0}, datetime: {1}, merchant: {2}, {3}'.format(item_id, datetime, merchant_id, e))
                    pass
                
                
        #Provide stats for monitoring
        current_time = time.time()
        elapsed_time = current_time - start_time
        requests = counter + 1
        print('-------------------')
        print('Requests Completed: {}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
        print('Elapased Time: {} minutes'.format(elapsed_time/60))
        if requests == len(item_ids):
            print('Scrape Complete')
            break
        print('Pausing...')    
        time.sleep(random.uniform(sleep_min, sleep_max))   
        clear_output(wait = True)

# %%
def scrape_all():
    scrape_gpu_specs()
    scrape_gpu_prices()

# %%
scrape_gpu_prices()
# Out:
# Connection successful.
# Failed to add into DB for item_id: zwbkcf, datetime: 1465954772000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1492889081000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1493665982000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1495307839000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1510184977000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1513297033000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515800363000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1516344396000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1521068094000, merchant: 1, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1465954772000, merchant: 5, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1495193281000, merchant: 5, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1529026772000, merchant: 5, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1465954772000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1494408489000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1494435523000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1494510322000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1494545416000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1494576985000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1494698516000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1495645347000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1495770431000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1495792907000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1495806398000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1495815411000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1496185248000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1496785440000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1497546244000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1499117484000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1499307358000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1499487386000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1499725729000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1499750866000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1499826786000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1499961614000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1499970653000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1500086752000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1502649003000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1502765132000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1502796774000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503080160000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503377145000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503399650000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503438259000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503485965000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503599795000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503617586000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503639948000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503657957000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503774019000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503971187000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1504020577000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1504140458000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1511905351000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1511952183000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1514550337000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1514695191000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1514947234000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1514961639000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1514972480000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1514983161000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515037189000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515069559000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515188369000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515206409000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515220917000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515228115000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515238914000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515455632000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515470030000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515484435000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515491689000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515498887000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515585165000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515765150000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1516042430000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1516218751000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1516430308000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1516451913000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1517635417000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1517642620000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1517660617000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1517955808000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1518006176000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1518291536000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1518507499000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1518521898000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1518676716000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1518683919000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1518698315000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1519163559000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1519239187000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1519260751000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1519267988000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1519278821000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1519293221000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1520624325000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1520879911000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1520897906000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1520923139000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1521027536000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1521196862000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1521888023000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1522754672000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1523383829000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1524248733000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1524309944000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1524641071000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1524673474000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1525112709000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1525389802000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1526754322000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1527615617000, merchant: 3, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1465954772000, merchant: 2, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1523426145000, merchant: 2, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1524203755000, merchant: 2, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1525067724000, merchant: 2, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1526796097000, merchant: 2, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1465954772000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1494542669000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1495115048000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1497930154000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1501303236000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1502257204000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503380366000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1513262010000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515681120000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1520087354000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1526190574000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1529026772000, merchant: 9, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1465954772000, merchant: 7, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1496741575000, merchant: 7, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1515450116000, merchant: 7, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1529026772000, merchant: 7, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1465954772000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1495804705000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1502730869000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1502990062000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503580439000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1503839631000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1505740370000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1508332278000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1510582195000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1513001303000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# Failed to add into DB for item_id: zwbkcf, datetime: 1529026772000, merchant: 4, unsupported operand type(s) for /: 'NoneType' and 'float'
# -------------------
# Requests Completed: 557; Frequency: 0.07629130959447752 requests/s
# Elapased Time: 121.682710425059 minutes
# Scrape Complete
